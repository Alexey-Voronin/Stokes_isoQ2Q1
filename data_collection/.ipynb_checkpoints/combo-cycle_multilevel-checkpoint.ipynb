# %%
import sys
sys.path.append('/Users/lexey/UIUC/firedrake/break_MG')

# solvers and data structures 
#from firedrake import *
import numpy as np


# plotting
import matplotlib.pyplot      as plt
plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=15)  
# self written stuff
from sysmg import *
from sysmg.util.data_analysis import conv_factor, collect_residuals
from sysmg.ph_multigrid import iso_mg

# %% [markdown]
# # Common parameters

# %%
#####################################
# Solver Params
GMRES        = {'module': "vcycle", "resid": 'abs'}
TOL          = 1e-10
MAXITER      = 100
mg_lvls      = 5
# system
NEx          = 64 

stokes_problems = dict()
print('BC types:')
for BC in ['periodic', 'Washer' ]:
    print('-%s' % BC)

    stokes_problems[BC] = form_stokes(Nelem=(NEx,NEx), domain= (1,1), lo_fe_precond= True,
                                      Solve= False, quadrilateral= True, BCs=BC)
# Out:
# BC types:
# -periodic
# -Washer

# %% [markdown]
# # $E_{IB}$

# %%
for BC in ['periodic', 'Washer' ]:
    print('\nBC_type=%s--------------------------------------' % BC)
    
    stokes_ho    = stokes_problems[BC]
    stokes_lo    = stokes_ho.lo_fe_sys
    
    # only need to update the entire solver when system changes
    gmg_lo_obj   = None
    first_time   = True

    #####################################
    for params in ["Table 2:",
                   "\t(no post-smoothing)",
                   (0.87, 1.02, 0.90, 1.20, 0.79, 0.74, 0.88, (1,0,1)),
                   (0.86, 0.75, 1.04, 0.99, 0.70, 1.15, 0.88, (1,0,2)),
                   "\t(symmetrical)",
                   (0.97, 0.91, 1.04, 1.02, 0.93, 0.78, 0.86, (1,1,1)),
                   (1.04, 0.55, 0.59, 0.72, 0.99, 0.85, 1.30, (2,2,1)),
#                   "Table 3:",
#                   "\t(omega_0=0 (no relax on Q2Q1))",
#                   (0.93, 0.00, 0.24, -1.0, -1.0, 0.67, 1.56, (0,0,1)),
#                   (0.63, 0.00, 0.40, -1.0, -1.0, 0.52, 1.35, (0,0,2)),
#                   "\t(omega_1=0 (no relax on isoQ2Q1))",
#                   (0.77, 0.45, 0.00, 0.46, 1.37, -1.0, -1.0, (1,1,1)),
#                   (0.99, 0.85, 0.00, 0.90, 1.12, -1.0, -1.0, (2,2,1))
                   ]:

        if type(params) == str:
            print(params)
            continue
     
        tau, omega_0, omega_1, alpha_0, beta_0, alpha_1, beta_1, (nu_1, nu_2, gamma)   = params         
        smoother_inner=('Braess-Sarazin', {'vcycle'         :   (1, 1), 'alpha'        : alpha_1,
                                           'pressure-solver': 'Jacobi', 'omega_smooth' :  beta_1,
                                           'psolve_iters'   :        1, 'omega_g'      : omega_1})
        inner_cycle  =  dict(multigrid_type='geometric', interpolation_type=(1,1),
                            coarsenining_rate=(2, 2), Q2_iso_Q1=True, 
                            tau     = tau, 
                            gamma   = gamma,
                            smoother= smoother_inner)
        outer_cycle  = ('Braess-Sarazin', {'vcycle'        : (nu_1, nu_2), 'alpha'        : alpha_0,
                                          'pressure-solver':     'Jacobi', 'omega_smooth' :  beta_0,
                                          'psolve_iters'   :            1, 'omega_g'      : omega_0})
        
        for cycle_type in ['W', 'V']: 
            # assemble/change mnultigrid parameters
            if first_time:
                gmg_lo_obj = iso_mg((stokes_lo, stokes_ho), mg_lvls, inner_cycle, outer_cycle, cycle_type=cycle_type)
                first_time = False
            else:
                gmg_lo_obj.update_params(inner_cycle, outer_cycle, cycle_type=cycle_type)
                
            gmg_lo     = gmg_lo_obj.get_solver()            
            
            def fsolver(b, x0):
                x, resid_lo  = solve(stokes_ho.A, b, x0=x0, M=gmg_lo, 
                                     maxiter=MAXITER, tol=TOL, GMRES=GMRES)
                return resid_lo

            resid_lo    = collect_residuals(fsolver, stokes_ho, plot=False, max_runs=55)
            cf_lsq, itc = conv_factor(resid_lo, multi=True)
            
            print('\t\t%s\tparams=%s\trho=%.4f\titers=%d' % (cycle_type, str(params), cf_lsq, itc))
# Out:
# BC_type=periodic--------------------------------------
# Table 2:
# 	(no post-smoothing)
# 		W	params=(0.87, 1.02, 0.9, 1.2, 0.79, 0.74, 0.88, (1, 0, 1))	rho=0.1715	iters=16
# 		V	params=(0.87, 1.02, 0.9, 1.2, 0.79, 0.74, 0.88, (1, 0, 1))	rho=0.1904	iters=16
# 		W	params=(0.86, 0.75, 1.04, 0.99, 0.7, 1.15, 0.88, (1, 0, 2))	rho=0.1912	iters=17
# 		V	params=(0.86, 0.75, 1.04, 0.99, 0.7, 1.15, 0.88, (1, 0, 2))	rho=0.3088	iters=20
# 	(symmetrical)
# 		W	params=(0.97, 0.91, 1.04, 1.02, 0.93, 0.78, 0.86, (1, 1, 1))	rho=0.0810	iters=11
# 		V	params=(0.97, 0.91, 1.04, 1.02, 0.93, 0.78, 0.86, (1, 1, 1))	rho=0.2645	iters=16
# 		W	params=(1.04, 0.55, 0.59, 0.72, 0.99, 0.85, 1.3, (2, 2, 1))	rho=0.0676	iters=10
# 		V	params=(1.04, 0.55, 0.59, 0.72, 0.99, 0.85, 1.3, (2, 2, 1))	rho=0.5215	iters=32
#
# BC_type=Washer--------------------------------------
# Table 2:
# 	(no post-smoothing)
# 		W	params=(0.87, 1.02, 0.9, 1.2, 0.79, 0.74, 0.88, (1, 0, 1))	rho=0.1703	iters=16
# 		V	params=(0.87, 1.02, 0.9, 1.2, 0.79, 0.74, 0.88, (1, 0, 1))	rho=0.2397	iters=17
# 		W	params=(0.86, 0.75, 1.04, 0.99, 0.7, 1.15, 0.88, (1, 0, 2))	rho=0.7618	iters=92
# 		V	params=(0.86, 0.75, 1.04, 0.99, 0.7, 1.15, 0.88, (1, 0, 2))	rho=0.5903	iters=50
# 	(symmetrical)
# 		W	params=(0.97, 0.91, 1.04, 1.02, 0.93, 0.78, 0.86, (1, 1, 1))	rho=0.0866	iters=12
# 		V	params=(0.97, 0.91, 1.04, 1.02, 0.93, 0.78, 0.86, (1, 1, 1))	rho=0.5469	iters=41
# 		W	params=(1.04, 0.55, 0.59, 0.72, 0.99, 0.85, 1.3, (2, 2, 1))	rho=0.0603	iters=10
# 		V	params=(1.04, 0.55, 0.59, 0.72, 0.99, 0.85, 1.3, (2, 2, 1))	rho=0.5471	iters=41

# %% [markdown]
# # $E_{V}$

# %%
from sysmg.util.solver import solve
MAXITER = 30

for BC in ['periodic', 'Washer']:
    print('\nBC=%s------------------------------------------' % BC)
    stokes_ho    = stokes_problems[BC]
    stokes_lo    = stokes_ho.lo_fe_sys
    
    # only need to update the entire solver when system changes
    gmg_lo_obj   = None
    first_time   = True

    #####################################
    for params in ["Table 2:",
                   "\t(no post-smoothing)",
#                   (0.86, 0.78, 1.01, (1,0,1)), 
                   (0.90, 0.98, 0.83, (1,0,2)), 
                   (0.85, 1.02, 0.82, (1,0,3)), 
                   "\t(symmetrical)",
                   (0.99, 0.67, 0.93, (1,1,1)), 
                   (1.05, 0.74, 0.78, (1,1,2)),
#                   "Table 3:",
#                   "\t(omega_0=0 (no relax on Q2Q1))",
#                   (0.64, 0.00, 0.98, (0,0,1)),
#                   (0.66, 0.00, 0.63, (0,0,2)),
#                   "\t(omega_1=0 (no relax on isoQ2Q1))",
#                   (0.48, 0.81, 0.00, (1,1,1)),
#                   (0.80, 0.85, 0.00, (2,2,1)),
                  ]:
        
        if type(params) == str:
            print(params)
            continue
        
        tau, omega_0, omega_1, (nu_1, nu_2, gamma)   = params

        smoother_inner  = ('Vanka', {'type'  : 'geometric', 'update': 'additive', 
                                     'vcycle':  (1, 1),     'omega_g' : omega_1})
        inner_cycle     =  dict(multigrid_type    = 'geometric', interpolation_type = (1,1),
                                coarsenining_rate = (2, 2),               Q2_iso_Q1 = True, 
                                tau      = tau, 
                                gamma    = gamma,
                                smoother = smoother_inner)
        outer_cycle     = ('Vanka', {'type'  : 'geometric',  'update' : 'additive', 
                                     'vcycle':  (nu_1, nu_2), 'omega_g' : omega_0})
        
        for cycle_type in ['W', 'V']: 
            # assemble/change mnultigrid parameters
            if first_time:
                gmg_lo_obj = iso_mg((stokes_lo, stokes_ho), mg_lvls, inner_cycle, outer_cycle, cycle_type=cycle_type)
                first_time = False
            else:
                gmg_lo_obj.update_params(inner_cycle, outer_cycle, cycle_type=cycle_type)
                
            gmg_lo     = gmg_lo_obj.get_solver()            
            
            def fsolver(b, x0):
                x, resid_lo  = solve(stokes_ho.A, b, x0=x0, M=gmg_lo, 
                                     maxiter=MAXITER, tol=TOL, GMRES=GMRES)
                return resid_lo

            resid_lo    = collect_residuals(fsolver, stokes_ho, plot=False, max_runs=55)
            cf_lsq, itc = conv_factor(resid_lo, multi=True)
            
            print('\t\t%s\tparams=%s\trho=%.4f\titers=%d' % (cycle_type, str(params), cf_lsq, itc))
# Out:
# BC=periodic------------------------------------------
# Table 2:
# 	(no post-smoothing)
# 		W	params=(0.9, 0.98, 0.83, (1, 0, 2))	rho=0.1918	iters=17
# 		V	params=(0.9, 0.98, 0.83, (1, 0, 2))	rho=0.4725	iters=27
# 		W	params=(0.85, 1.02, 0.82, (1, 0, 3))	rho=0.1884	iters=17
# 		V	params=(0.85, 1.02, 0.82, (1, 0, 3))	rho=0.2645	iters=18
# 	(symmetrical)
# 		W	params=(0.99, 0.67, 0.93, (1, 1, 1))	rho=0.3355	iters=22
# 		V	params=(0.99, 0.67, 0.93, (1, 1, 1))	rho=0.9901	iters=30
# 		W	params=(1.05, 0.74, 0.78, (1, 1, 2))	rho=0.1060	iters=12
# 		V	params=(1.05, 0.74, 0.78, (1, 1, 2))	rho=0.1941	iters=15
#
# BC=Washer------------------------------------------
# Table 2:
# 	(no post-smoothing)
# 		W	params=(0.9, 0.98, 0.83, (1, 0, 2))	rho=0.2112	iters=17
# 		V	params=(0.9, 0.98, 0.83, (1, 0, 2))	rho=0.2107	iters=17
# 		W	params=(0.85, 1.02, 0.82, (1, 0, 3))	rho=0.2014	iters=17
# 		V	params=(0.85, 1.02, 0.82, (1, 0, 3))	rho=0.2013	iters=17
# 	(symmetrical)
# 		W	params=(0.99, 0.67, 0.93, (1, 1, 1))	rho=0.2995	iters=21
# 		V	params=(0.99, 0.67, 0.93, (1, 1, 1))	rho=0.5306	iters=30
# 		W	params=(1.05, 0.74, 0.78, (1, 1, 2))	rho=0.1000	iters=12
# 		V	params=(1.05, 0.74, 0.78, (1, 1, 2))	rho=0.1928	iters=15
